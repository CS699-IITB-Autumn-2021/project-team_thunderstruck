# %%
import requests
from bs4 import BeautifulSoup
import os
import numpy as np
import matplotlib.pyplot as plt
import re
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
URL = "https://www.mygov.in/covid-19"
    
response = requests.get(URL).content
soup_india = BeautifulSoup(response, 'html.parser')

states = soup_india.find_all("span", {"class": "st_name"})
states = [str(x.string) for x in states]
print(states)

states_total_cases = soup_india.find_all("div", {"class": "tick-confirmed"})
states_total_cases = [int(x.small.string.replace(",","")) for x in states_total_cases]
print(states_total_cases)

states_active_cases = soup_india.find_all("div", {"class": "tick-active"})
states_active_cases = [int(x.small.string.replace(",","")) for x in states_active_cases]
print(states_active_cases)

states_discharged = soup_india.find_all("div", {"class": "tick-discharged"})
states_discharged = [int(x.small.string.replace(",","")) for x in states_discharged]
print(states_discharged)

states_deaths = soup_india.find_all("div", {"class": "tick-death"})
states_deaths = [int(x.small.string.replace(",","")) for x in states_deaths]
print(states_deaths)

india_data_df = pd.DataFrame(list(zip(states, states_total_cases, states_active_cases, states_discharged, states_deaths)),columns =['Name', 'Total Cases', 'Active Cases','Total discharged','Total Deaths',])
india_data_df
# Out:
# ['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telengana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']
# [7635, 2058065, 54942, 605465, 726004, 65285, 1005570, 10675, 1439252, 177228, 826184, 771009, 220792, 330666, 348381, 2981732, 4809619, 20856, 10365, 792647, 6581677, 122228, 82580, 108790, 31492, 1032673, 127151, 601913, 954370, 31698, 2680857, 668266, 84285, 1709985, 343695, 1577711]
# [8, 6932, 236, 4011, 38, 39, 190, 5, 365, 646, 189, 263, 1312, 993, 120, 9741, 97239, 46, 3, 109, 34120, 1433, 1021, 14484, 247, 4648, 617, 215, 36, 224, 15842, 4190, 117, 144, 158, 7672]
# [7498, 2036865, 54426, 595520, 716305, 64426, 991810, 10666, 1413798, 173252, 815909, 760871, 215770, 325247, 343126, 2934085, 4685932, 20602, 10311, 782015, 6407936, 118908, 80134, 93939, 30572, 1019764, 124686, 585167, 945380, 31085, 2629201, 660143, 83352, 1686945, 336140, 1551115]
# [129, 14268, 280, 5934, 9661, 820, 13570, 4, 25089, 3330, 10086, 9875, 3710, 4426, 5135, 37906, 26448, 208, 51, 10523, 139621, 1887, 1425, 367, 673, 8261, 1848, 16531, 8954, 389, 35814, 3933, 816, 22896, 7397, 18924]
#                                         Name  ...  Total Deaths
# 0                        Andaman and Nicobar  ...           129
# 1                             Andhra Pradesh  ...         14268
# 2                          Arunachal Pradesh  ...           280
# 3                                      Assam  ...          5934
# 4                                      Bihar  ...          9661
# 5                                 Chandigarh  ...           820
# 6                               Chhattisgarh  ...         13570
# 7   Dadra and Nagar Haveli and Daman and Diu  ...             4
# 8                                      Delhi  ...         25089
# 9                                        Goa  ...          3330
# 10                                   Gujarat  ...         10086
# 11                                   Haryana  ...          9875
# 12                          Himachal Pradesh  ...          3710
# 13                         Jammu and Kashmir  ...          4426
# 14                                 Jharkhand  ...          5135
# 15                                 Karnataka  ...         37906
# 16                                    Kerala  ...         26448
# 17                                    Ladakh  ...           208
# 18                               Lakshadweep  ...            51
# 19                            Madhya Pradesh  ...         10523
# 20                               Maharashtra  ...        139621
# 21                                   Manipur  ...          1887
# 22                                 Meghalaya  ...          1425
# 23                                   Mizoram  ...           367
# 24                                  Nagaland  ...           673
# 25                                    Odisha  ...          8261
# 26                                Puducherry  ...          1848
# 27                                    Punjab  ...         16531
# 28                                 Rajasthan  ...          8954
# 29                                    Sikkim  ...           389
# 30                                Tamil Nadu  ...         35814
# 31                                 Telengana  ...          3933
# 32                                   Tripura  ...           816
# 33                             Uttar Pradesh  ...         22896
# 34                               Uttarakhand  ...          7397
# 35                               West Bengal  ...         18924
#
# [36 rows x 5 columns]

# %%
url = 'https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/'

# get URL html
page = requests.get(url)
soup_int = BeautifulSoup(page.text, 'html.parser')
input_data = soup_int.find_all('td')
country=[]
country_confirmed=[]
country_deaths=[]

for iter1 in range(len(input_data)):
    if iter1%4==0:
        country.append(str(input_data[iter1].string))
    if iter1%4==1:
        country_confirmed.append(int(input_data[iter1].string.replace(",","")))
    if iter1%4==2:
        country_deaths.append(int(input_data[iter1].string.replace(",","")))
    if iter1%4==3:
        continue
print(country)
print(country_confirmed)
print(country_deaths)
country_data_df = pd.DataFrame(list(zip(country, country_confirmed, country_deaths)),columns =['Name', 'Confirmed Cases',"Deaths"])
country_data_df
# Out:
# ['United States', 'India', 'Brazil', 'United Kingdom', 'Russia', 'Turkey', 'France', 'Iran', 'Argentina', 'Spain', 'Colombia', 'Italy', 'Germany', 'Indonesia', 'Mexico', 'Poland', 'South Africa', 'Philippines', 'Ukraine', 'Malaysia', 'Peru', 'Netherlands', 'Iraq', 'Thailand', 'Japan (+Diamond Princess)', 'Czech Republic (Czechia)', 'Canada', 'Chile', 'Bangladesh', 'Romania', 'Israel', 'Belgium', 'Pakistan', 'Sweden', 'Portugal', 'Serbia', 'Morocco', 'Cuba', 'Kazakhstan', 'Switzerland', 'Vietnam', 'Jordan', 'Hungary', 'Nepal', 'Austria', 'United Arab Emirates', 'Tunisia', 'Greece', 'Georgia', 'Lebanon', 'Guatemala', 'Belarus', 'Costa Rica', 'Saudi Arabia', 'Bulgaria', 'Sri Lanka', 'Ecuador', 'Bolivia', 'Azerbaijan', 'Myanmar', 'Panama', 'Paraguay', 'Slovakia', 'Croatia', 'State of Palestine', 'Kuwait', 'Ireland', 'Uruguay', 'Venezuela', 'Honduras', 'Dominican Republic', 'Denmark', 'Lithuania', 'Ethiopia', 'Libya', 'South Korea', 'Mongolia', 'Egypt', 'Moldova', 'Oman', 'Slovenia', 'Bahrain', 'Armenia', 'Kenya', 'Bosnia and Herzegovina', 'Qatar', 'Zambia', 'Nigeria', 'Algeria', 'North Macedonia', 'Norway', 'Botswana', 'Kyrgyzstan', 'Uzbekistan', 'Latvia', 'Albania', 'Estonia', 'Afghanistan', 'Mozambique', 'Finland', 'Montenegro', 'Australia', 'Singapore', 'Zimbabwe', 'Ghana', 'Namibia', 'Uganda', 'Cyprus', 'Cambodia', 'El Salvador', 'Rwanda', 'China', 'Cameroon', 'Jamaica', 'Maldives', 'Luxembourg', 'Senegal', 'Angola', 'Malawi', "Côte d'Ivoire", 'DR Congo', 'Réunion', 'Guadeloupe', 'Trinidad and Tobago', 'Fiji', 'Eswatini', 'Suriname', 'French Guiana', 'Madagascar', 'Martinique', 'French Polynesia', 'Sudan', 'Cabo Verde', 'Syria', 'Malta', 'Mauritania', 'Guyana', 'Gabon', 'Guinea', 'Laos', 'Tanzania', 'Togo', 'Benin', 'Papua New Guinea', 'Haiti', 'Belize', 'Seychelles', 'Bahamas', 'Lesotho', 'Somalia', 'Mayotte', 'Timor-Leste', 'Burundi', 'Tajikistan', 'Curaçao', 'Mauritius', 'Taiwan', 'Nicaragua', 'Aruba', 'Mali', 'Andorra', 'Congo', 'Burkina Faso', 'Djibouti', 'Equatorial Guinea', 'Iceland', 'Hong Kong', 'South Sudan', 'Saint Lucia', 'Channel Islands', 'Barbados', 'Central African Republic', 'Gambia', 'Brunei ', 'New Caledonia', 'Yemen', 'Isle of Man', 'Eritrea', 'Sierra Leone', 'Niger', 'Guinea-Bissau', 'Liberia', 'Gibraltar', 'Grenada', 'Bermuda', 'San Marino', 'Chad', 'New Zealand', 'Sint Maarten', 'Comoros', 'St. Vincent & Grenadines', 'Dominica', 'Saint Martin', 'Antigua and Barbuda', 'Sao Tome & Principe', 'Liechtenstein', 'Monaco', 'Turks and Caicos', 'British Virgin Islands', 'Bhutan', 'Saint Kitts & Nevis', 'Caribbean Netherlands', 'Saint Barthelemy', 'Faeroe Islands', 'Cayman Islands', 'Greenland', 'Anguilla', 'Wallis & Futuna', 'Macao', 'Falkland Islands', 'Montserrat', 'Saint Pierre & Miquelon', 'Holy See', 'Solomon Islands', 'Western Sahara', 'MS Zaandam', 'Palau', 'Vanuatu', 'Marshall Islands', 'Samoa', 'Saint Helena', 'Micronesia']
# [45431167, 34001743, 21590097, 8231437, 7861681, 7508975, 7063511, 5729785, 5267339, 4977448, 4974400, 4704318, 4342178, 4229813, 3732429, 2928065, 2912938, 2690455, 2578394, 2353579, 2185355, 2029289, 2026349, 1740428, 1712647, 1705532, 1667575, 1663992, 1563501, 1382531, 1310670, 1269002, 1260669, 1159560, 1076358, 1017798, 939922, 923966, 908847, 851609, 846230, 835969, 830725, 803552, 766542, 738026, 710096, 682394, 645195, 630950, 581498, 561753, 547914, 547704, 527802, 527735, 512071, 504601, 494067, 481230, 469440, 460244, 429886, 419035, 415182, 412158, 405970, 390234, 385952, 370968, 366711, 365051, 357801, 355843, 347364, 335742, 330869, 314116, 308724, 303999, 302654, 275803, 275077, 251313, 241946, 237579, 209396, 208153, 204790, 195132, 194630, 181251, 179492, 179371, 175890, 175664, 167828, 155599, 151018, 148672, 135981, 133444, 132205, 132016, 128368, 128167, 124808, 119978, 115607, 107664, 98840, 96457, 95399, 86456, 85732, 79300, 73842, 61794, 61694, 60878, 57247, 54024, 53734, 52999, 51535, 46313, 44873, 42962, 42898, 41129, 40178, 38824, 37920, 37509, 37375, 36465, 33823, 32576, 30535, 29398, 26034, 25807, 24335, 23365, 22675, 22187, 21638, 21580, 21481, 21269, 20397, 19681, 19257, 17084, 16837, 16437, 16313, 15737, 15663, 15511, 15307, 15255, 14546, 13320, 12786, 12287, 12273, 12134, 12054, 12017, 11474, 11401, 9943, 9472, 9417, 9412, 8184, 6758, 6396, 6122, 6121, 5801, 5682, 5653, 5536, 5470, 5061, 4759, 4420, 4173, 4096, 4086, 3789, 3772, 3639, 3468, 3337, 2898, 2725, 2613, 2435, 2274, 1587, 1311, 996, 630, 594, 445, 77, 68, 41, 32, 27, 20, 10, 9, 8, 4, 4, 3, 2, 1]
# [737589, 451220, 601442, 137944, 219329, 66605, 117150, 123081, 115547, 86827, 126692, 131384, 95183, 142763, 282773, 75958, 88429, 40069, 59523, 27525, 199727, 18215, 22620, 17917, 17999, 30518, 28289, 37574, 27713, 40071, 7959, 25713, 28173, 14879, 18056, 8841, 14485, 7928, 11613, 11153, 20763, 10827, 30330, 11257, 11135, 2115, 25046, 15210, 9332, 8394, 14118, 4319, 6718, 8751, 21906, 13377, 32848, 18806, 6692, 18188, 7275, 16207, 12772, 8802, 4264, 2455, 5280, 6064, 4652, 10045, 4072, 2674, 5308, 6066, 4808, 2605, 1482, 17765, 7076, 4103, 4618, 1390, 5646, 5195, 11009, 607, 3654, 2756, 5859, 6855, 871, 2381, 2624, 1276, 2836, 2783, 1404, 7230, 1924, 1109, 2000, 1478, 183, 4645, 1158, 3527, 3179, 560, 2559, 3420, 1311, 4636, 1517, 2034, 235, 837, 1868, 1642, 2292, 672, 1087, 370, 721, 1566, 653, 1230, 974, 291, 958, 608, 629, 2928, 347, 2358, 459, 785, 848, 205, 385, 33, 724, 237, 159, 252, 647, 427, 118, 590, 653, 1180, 180, 119, 38, 124, 169, 115, 846, 206, 170, 554, 130, 219, 200, 178, 155, 33, 213, 130, 231, 98, 101, 100, 339, 64, 209, 1787, 54, 43, 121, 204, 141, 286, 97, 183, 92, 91, 174, 28, 70, 147, 38, 27, 55, 93, 56, 60, 33, 23, 37, 3, 20, 19, 6, 2, 2, 0, 1, 7, 0, 0, 1, 0, 0, 0, 1, 2, 0, 1, 0, 0, 0, 0]
#                  Name  Confirmed Cases  Deaths
# 0       United States         45431167  737589
# 1               India         34001743  451220
# 2              Brazil         21590097  601442
# 3      United Kingdom          8231437  137944
# 4              Russia          7861681  219329
# ..                ...              ...     ...
# 217           Vanuatu                4       1
# 218  Marshall Islands                4       0
# 219             Samoa                3       0
# 220      Saint Helena                2       0
# 221        Micronesia                1       0
#
# [222 rows x 3 columns]

# %%
px.pie(country_data_df.sort_values(by=['Confirmed Cases'],ascending=False)[:20], values="Confirmed Cases", names="Name", title="COnfirmed cases of top 20 countries")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c4aeac4e-5579-44c9-a4b6-16a77d426df1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c4aeac4e-5579-44c9-a4b6-16a77d426df1")) {
#                     Plotly.newPlot(
#                         'c4aeac4e-5579-44c9-a4b6-16a77d426df1',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Name=%{label}<br>Confirmed Cases=%{value}", "labels": ["United States", "India", "Brazil", "United Kingdom", "Russia", "Turkey", "France", "Iran", "Argentina", "Spain", "Colombia", "Italy", "Germany", "Indonesia", "Mexico", "Poland", "South Africa", "Philippines", "Ukraine", "Malaysia"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [45431167, 34001743, 21590097, 8231437, 7861681, 7508975, 7063511, 5729785, 5267339, 4977448, 4974400, 4704318, 4342178, 4229813, 3732429, 2928065, 2912938, 2690455, 2578394, 2353579]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
px.pie(country_data_df.sort_values(by=['Deaths'],ascending=False)[:20], values="Deaths", names="Name", title="Covid deaths of top 20 countries")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cf6e40d5-3171-43fa-b9c6-fe0558392331" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf6e40d5-3171-43fa-b9c6-fe0558392331")) {
#                     Plotly.newPlot(
#                         'cf6e40d5-3171-43fa-b9c6-fe0558392331',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Name=%{label}<br>Deaths=%{value}", "labels": ["United States", "Brazil", "India", "Mexico", "Russia", "Peru", "Indonesia", "United Kingdom", "Italy", "Colombia", "Iran", "France", "Argentina", "Germany", "South Africa", "Spain", "Poland", "Turkey", "Ukraine", "Romania"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [737589, 601442, 451220, 282773, 219329, 199727, 142763, 137944, 131384, 126692, 123081, 117150, 115547, 95183, 88429, 86827, 75958, 66605, 59523, 40071]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
px.pie(india_data_df.sort_values(by=['Total Cases'],ascending=False), values="Total Cases", names="Name", title="Covid Total Cases of top 20 countries")
# india_data_df
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="299f129a-82bf-489c-883c-e34f2bac8096" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("299f129a-82bf-489c-883c-e34f2bac8096")) {
#                     Plotly.newPlot(
#                         '299f129a-82bf-489c-883c-e34f2bac8096',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Name=%{label}<br>Total Cases=%{value}", "labels": ["Maharashtra", "Kerala", "Karnataka", "Tamil Nadu", "Andhra Pradesh", "Uttar Pradesh", "West Bengal", "Delhi", "Odisha", "Chhattisgarh", "Rajasthan", "Gujarat", "Madhya Pradesh", "Haryana", "Bihar", "Telengana", "Assam", "Punjab", "Jharkhand", "Uttarakhand", "Jammu and Kashmir", "Himachal Pradesh", "Goa", "Puducherry", "Manipur", "Mizoram", "Tripura", "Meghalaya", "Chandigarh", "Arunachal Pradesh", "Sikkim", "Nagaland", "Ladakh", "Dadra and Nagar Haveli and Daman and Diu", "Lakshadweep", "Andaman and Nicobar"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [6581677, 4809619, 2981732, 2680857, 2058065, 1709985, 1577711, 1439252, 1032673, 1005570, 954370, 826184, 792647, 771009, 726004, 668266, 605465, 601913, 348381, 343695, 330666, 220792, 177228, 127151, 122228, 108790, 84285, 82580, 65285, 54942, 31698, 31492, 20856, 10675, 10365, 7635]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
india_data_df
# Out:
#                                         Name  ...  Total Deaths
# 0                        Andaman and Nicobar  ...           129
# 1                             Andhra Pradesh  ...         14268
# 2                          Arunachal Pradesh  ...           280
# 3                                      Assam  ...          5934
# 4                                      Bihar  ...          9661
# 5                                 Chandigarh  ...           820
# 6                               Chhattisgarh  ...         13570
# 7   Dadra and Nagar Haveli and Daman and Diu  ...             4
# 8                                      Delhi  ...         25089
# 9                                        Goa  ...          3330
# 10                                   Gujarat  ...         10086
# 11                                   Haryana  ...          9875
# 12                          Himachal Pradesh  ...          3710
# 13                         Jammu and Kashmir  ...          4426
# 14                                 Jharkhand  ...          5135
# 15                                 Karnataka  ...         37906
# 16                                    Kerala  ...         26448
# 17                                    Ladakh  ...           208
# 18                               Lakshadweep  ...            51
# 19                            Madhya Pradesh  ...         10523
# 20                               Maharashtra  ...        139621
# 21                                   Manipur  ...          1887
# 22                                 Meghalaya  ...          1425
# 23                                   Mizoram  ...           367
# 24                                  Nagaland  ...           673
# 25                                    Odisha  ...          8261
# 26                                Puducherry  ...          1848
# 27                                    Punjab  ...         16531
# 28                                 Rajasthan  ...          8954
# 29                                    Sikkim  ...           389
# 30                                Tamil Nadu  ...         35814
# 31                                 Telengana  ...          3933
# 32                                   Tripura  ...           816
# 33                             Uttar Pradesh  ...         22896
# 34                               Uttarakhand  ...          7397
# 35                               West Bengal  ...         18924
#
# [36 rows x 5 columns]

# %%
px.bar(india_data_df.sort_values(by=['Total Cases'],ascending=False), x="Name", y="Total Cases",color='Total Deaths', title="State-wise total cases and total deaths")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f7f76974-cc63-42fc-8099-57d9ceba665f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7f76974-cc63-42fc-8099-57d9ceba665f")) {
#                     Plotly.newPlot(
#                         'f7f76974-cc63-42fc-8099-57d9ceba665f',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Name=%{x}<br>Total Cases=%{y}<br>Total Deaths=%{marker.color}", "legendgroup": "", "marker": {"color": [139621, 26448, 37906, 35814, 14268, 22896, 18924, 25089, 8261, 13570, 8954, 10086, 10523, 9875, 9661, 3933, 5934, 16531, 5135, 7397, 4426, 3710, 3330, 1848, 1887, 367, 816, 1425, 820, 280, 389, 673, 208, 4, 51, 129], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Kerala", "Karnataka", "Tamil Nadu", "Andhra Pradesh", "Uttar Pradesh", "West Bengal", "Delhi", "Odisha", "Chhattisgarh", "Rajasthan", "Gujarat", "Madhya Pradesh", "Haryana", "Bihar", "Telengana", "Assam", "Punjab", "Jharkhand", "Uttarakhand", "Jammu and Kashmir", "Himachal Pradesh", "Goa", "Puducherry", "Manipur", "Mizoram", "Tripura", "Meghalaya", "Chandigarh", "Arunachal Pradesh", "Sikkim", "Nagaland", "Ladakh", "Dadra and Nagar Haveli and Daman and Diu", "Lakshadweep", "Andaman and Nicobar"], "xaxis": "x", "y": [6581677, 4809619, 2981732, 2680857, 2058065, 1709985, 1577711, 1439252, 1032673, 1005570, 954370, 826184, 792647, 771009, 726004, 668266, 605465, 601913, 348381, 343695, 330666, 220792, 177228, 127151, 122228, 108790, 84285, 82580, 65285, 54942, 31698, 31492, 20856, 10675, 10365, 7635], "yaxis": "y"}],
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Total Deaths"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"ma ...

# %%
px.bar(india_data_df.sort_values(by=['Active Cases'],ascending=False), x="Name", y="Active Cases",title="State-wise Active cases and total deaths")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e6e2f68b-705c-4249-bfd7-a6baa4184a4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e6e2f68b-705c-4249-bfd7-a6baa4184a4b")) {
#                     Plotly.newPlot(
#                         'e6e2f68b-705c-4249-bfd7-a6baa4184a4b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Name=%{x}<br>Active Cases=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Kerala", "Maharashtra", "Tamil Nadu", "Mizoram", "Karnataka", "West Bengal", "Andhra Pradesh", "Odisha", "Telengana", "Assam", "Manipur", "Himachal Pradesh", "Meghalaya", "Jammu and Kashmir", "Goa", "Puducherry", "Delhi", "Haryana", "Nagaland", "Arunachal Pradesh", "Sikkim", "Punjab", "Chhattisgarh", "Gujarat", "Uttarakhand", "Uttar Pradesh", "Jharkhand", "Tripura", "Madhya Pradesh", "Ladakh", "Chandigarh", "Bihar", "Rajasthan", "Andaman and Nicobar", "Dadra and Nagar Haveli and Daman and Diu", "Lakshadweep"], "xaxis": "x", "y": [97239, 34120, 15842, 14484, 9741, 7672, 6932, 4648, 4190, 4011, 1433, 1312, 1021, 993, 646, 617, 365, 263, 247, 236, 224, 215, 190, 189, 158, 144, 120, 117, 109, 46, 39, 38, 36, 8, 5, 3], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...
